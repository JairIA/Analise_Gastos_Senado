# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
df = pd.read_csv('2016.csv', skiprows =1, encoding='latin1', delimiter=';')

# %%
df.head()
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2016    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2016    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2016    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2016    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2016    1  ACIR GURGACZ  Aquisição de material de consumo para uso no e...
#
#              CNPJ_CPF                        FORNECEDOR  DOCUMENTO  \
# 0  05.914.650/0001-66  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA  000011328
# 1  05.914.650/0001-66  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA  000011327
# 2      004.948.028-63     GILBERTO PISELO DO NASCIMENTO     001/16
# 3  05.423.963/0001-11                     OI MÓVEL S.A.  661639001
# 4  62.652.961/0001-38               AGÊNCIA ESTADO S.A.   00608918
#
#          DATA                                       DETALHAMENTO  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26688 entries, 0 to 26687
# Data columns (total 10 columns):
# ANO                  26688 non-null int64
# MES                  26688 non-null int64
# SENADOR              26688 non-null object
# TIPO_DESPESA         26688 non-null object
# CNPJ_CPF             26688 non-null object
# FORNECEDOR           26688 non-null object
# DOCUMENTO            24647 non-null object
# DATA                 26688 non-null object
# DETALHAMENTO         21308 non-null object
# VALOR_REEMBOLSADO    26688 non-null object
# dtypes: int64(2), object(8)
# memory usage: 2.0+ MB

# %%
df.describe()
df.shape
# Out:
# (26688, 10)

# %%
df.dtypes
# Out:
# ANO                   int64
# MES                   int64
# SENADOR              object
# TIPO_DESPESA         object
# CNPJ_CPF             object
# FORNECEDOR           object
# DOCUMENTO            object
# DATA                 object
# DETALHAMENTO         object
# VALOR_REEMBOLSADO    object
# dtype: object

# %%
df['VALOR_REEMBOLSADO']=df['VALOR_REEMBOLSADO'].str.replace(',', '.')

# %%
df['VALOR_REEMBOLSADO'] = pd.to_numeric(df['VALOR_REEMBOLSADO'])

# %%
df['DATA'] = pd.to_datetime(df['DATA'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-152-579c33c19d56> in <module>()
# ----> 1 df['DATA'] = pd.to_datetime(df['DATA'])
#
# ...

# %%
df[df['DATA'] == '20/07/5017']
# Out:
# Empty DataFrame
# Columns: [ANO, MES, SENADOR, TIPO_DESPESA, CNPJ_CPF, FORNECEDOR, DOCUMENTO, DATA, DETALHAMENTO, VALOR_REEMBOLSADO]
# Index: []

# %%
df.loc[2191, 'DATA']
# Out:
# '20/07/5017'

# %%
df.loc[df['DATA'].str[-4:] == '5017', 'DATA'] = '20/07/2017'

# %%
df.loc[df['DATA'].str[-4:] == '3016'] = '04/02/2016'

# %%
df.loc[df['DATA'].str[-4:] == '2106', 'DATA'] = '2016'

# %%
df.loc[(df['DATA'].str[-4:] != '2016') & (df['DATA'].str[-4:] != '2015') & (df['DATA'].str[-4:] != '2017')]
# Out:
#         ANO  MES                 SENADOR  \
# 722    2016    8  ALOYSIO NUNES FERREIRA
# 2172   2016    9        ARMANDO MONTEIRO
# 2191   2016   10        ARMANDO MONTEIRO
# 8174   2016    9          GLADSON CAMELI
# 12421  2016    4           JOSÉ MEDEIROS
# 12583  2016    7           JOSÉ MEDEIROS
# 12789  2016    9           JOSÉ MEDEIROS
# 13601  2016    4              JOSÉ SERRA
# 13698  2016    9             KÁTIA ABREU
# 13716  2016   10             KÁTIA ABREU
# 17925  2016   10              PAULO PAIM
# 17957  2016   10              PAULO PAIM
# 19431  2016    1            REGINA SOUSA
# 20144  2016    3          RICARDO FRANCO
# 20671  2016    3         ROBERTO REQUIÃO
# 21755  2016   11             ROMERO JUCÁ
# 24548  2016    4           WALDEMIR MOKA
# 24549  2016    4           WALDEMIR MOKA
# 24962  2016    5         WALTER PINHEIRO
# 26544  2016   10           ZEZÉ PERRELLA
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# ...

# %%
df[df['DATA'].str[-4:] == '0200'] = '2016'

# %%
df['DATA'] = pd.to_datetime(df['DATA'],errors='coerce')
df.dtypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26688 entries, 0 to 26687
# Data columns (total 10 columns):
# ANO                  26688 non-null object
# MES                  26688 non-null object
# SENADOR              26688 non-null object
# TIPO_DESPESA         26688 non-null object
# CNPJ_CPF             26688 non-null object
# FORNECEDOR           26688 non-null object
# DOCUMENTO            24647 non-null object
# DATA                 26684 non-null datetime64[ns]
# DETALHAMENTO         21308 non-null object
# VALOR_REEMBOLSADO    26688 non-null object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 2.0+ MB

# %%
df.dtypes
# Out:
# ANO                          object
# MES                          object
# SENADOR                      object
# TIPO_DESPESA                 object
# CNPJ_CPF                     object
# FORNECEDOR                   object
# DOCUMENTO                    object
# DATA                 datetime64[ns]
# DETALHAMENTO                 object
# VALOR_REEMBOLSADO           float64
# dtype: object

# %%
df['TIPO_DESPESA'].unique()
# Out:
# array(['Aluguel', 'Despesas Gerais', 'Contratações',
#        'Locomoção, hospedagem, alimentação', 'Viagens', 'Segurança', nan],
#       dtype=object)

# %%
df['TIPO_DESPESA'] = df['TIPO_DESPESA'].map({'Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.': 'Aluguel',
                                             'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ': 'Despesas Gerais', 
                                             'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar': 'Contratações', 
                                             'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes': 'Locomoção, hospedagem, alimentação', 
                                             'Passagens aéreas, aquáticas e terrestres nacionais': 'Viagens', 
                                             'Divulgação da atividade parlamentar': 'Segurança'})
